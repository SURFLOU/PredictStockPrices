# %%
bronze_table = spark.table('plstocks.bronze_sector_lookup')

# %%
display(bronze_table)

# %%
silver_table = bronze_table.dropDuplicates(['ticker', 'sector'])
display(silver_table)

# %%
silver_table.write \
.mode("overwrite") \
.saveAsTable("plstocks.silver_sector_lookup")
