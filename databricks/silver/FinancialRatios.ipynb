# %%
df = spark.table("plstocks.bronze_financial_ratios")

# %%
# display(df)

# %%
# df.printSchema()

# %%
# display(df.describe())

# %%
# from pyspark.sql.functions import col, sum, isnan

# # Sprawdzenie wartości NULL
# null_counts = df.select([sum(col(c).isNull().cast("int")).alias(c) for c in df.columns])
# display(null_counts)

# # Sprawdzenie wartości NaN
# nan_counts = df.select([sum(isnan(c).cast("int")).alias(c) for c in df.columns if df.schema[c].dataType.simpleString() == 'double'])
# display(nan_counts)

# %%
# from pyspark.sql.functions import col
# from functools import reduce

# df_with_nulls = df.filter(
#     reduce(lambda a, b: a | b, [col(c).isNull() for c in df.columns])
# )

# df_with_nulls.show()

# %%
# %python
from pyspark.sql.functions import col, isnan, when

# Change NaN to NULL for FLOAT and DOUBLE columns
df = df.select([
    when(isnan(c), None).otherwise(col(c)).alias(c) if dict(df.dtypes)[c] in ['double', 'float'] 
    else col(c).alias(c) 
    for c in df.columns
])

# display(df)

# %%
df.write.format("delta").mode("overwrite").saveAsTable("plstocks.silver_financial_ratios")
