# %%
host = dbutils.secrets.get(scope = "postgresql", key = "host")
database = dbutils.secrets.get(scope = "postgresql", key = "database")
user = dbutils.secrets.get(scope = "postgresql", key = "user")
password = dbutils.secrets.get(scope = "postgresql", key = "password")

# %%
sector_lookup = (spark.read
  .format("postgresql")
  .option("dbtable", "public.sector_lookup")
  .option("host", host)
  .option("port", "5432") 
  .option("database", database)
  .option("user", user) 
  .option("password", password)
  .load()
)

# %%
display(sector_lookup)

# %%
sector_lookup.write \
.mode("overwrite") \
.format("delta") \
.saveAsTable("plstocks.bronze_sector_lookup")
